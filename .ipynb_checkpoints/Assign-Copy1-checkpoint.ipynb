# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
df.tail()
# Out:
#          tweet_id  sentiment  \
# 39995  1753918954    neutral
# 39996  1753919001       love
# 39997  1753919005       love
# 39998  1753919043  happiness
# 39999  1753919049       love
#
#                                                  content
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...

# %%
sns.countplot(x='sentiment',data=df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
# !pip install neattext

# %%
import neattext.functions as nfx

# %%
# dir(nfx)

# %%
df["new_content"] = df["content"].apply(nfx.remove_userhandles)

# %%
df["new_content"] = df["content"].apply(nfx.remove_stopwords)

# %%
df.head(3)
# Out:
#      tweet_id sentiment                                            content  \
# 0  1956967341     empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666   sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696   sadness                Funeral ceremony...gloomy friday...
#
#                                          new_content
# 0  @tiffanylue know listenin bad habit earlier st...
# 1       Layin n bed headache ughhhh...waitin call...
# 2                Funeral ceremony...gloomy friday...

# %%
df.tail()
# Out:
#          tweet_id  sentiment  \
# 39995  1753918954    neutral
# 39996  1753919001       love
# 39997  1753919005       love
# 39998  1753919043  happiness
# 39999  1753919049       love
#
#                                                  content  \
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
#                                              new_content
# 39995                                   @JohnLloydTaylor
# 39996                             Happy Mothers Day love
# 39997  Happy Mother's Day mommies there, woman man lo...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!! PEEP...
# 39999  @mopedronin bullet train tokyo gf visiting jap...

# %%
df["content"].isna().sum()
# Out:
# 0

# %%
(df["content"]=="").sum()
# Out:
# 0

# %%
df.tail()
# Out:
#          tweet_id  sentiment  \
# 39995  1753918954    neutral
# 39996  1753919001       love
# 39997  1753919005       love
# 39998  1753919043  happiness
# 39999  1753919049       love
#
#                                                  content  \
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
#                                              new_content
# 39995                                   @JohnLloydTaylor
# 39996                             Happy Mothers Day love
# 39997  Happy Mother's Day mommies there, woman man lo...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!! PEEP...
# 39999  @mopedronin bullet train tokyo gf visiting jap...

# %%
df["new_content"] = df["new_content"].str.lower()

# %%
df.head()
# Out:
#      tweet_id   sentiment                                            content  \
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...
#
#                                          new_content
# 0  @tiffanylue know listenin bad habit earlier st...
# 1       layin n bed headache ughhhh...waitin call...
# 2                funeral ceremony...gloomy friday...
# 3                           wants hang friends soon!
# 4   @dannycastillo want trade houston tickets, will.

# %%
df.tail()
# Out:
#          tweet_id  sentiment  \
# 39995  1753918954    neutral
# 39996  1753919001       love
# 39997  1753919005       love
# 39998  1753919043  happiness
# 39999  1753919049       love
#
#                                                  content  \
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
#                                              new_content
# 39995                                   @johnlloydtaylor
# 39996                             happy mothers day love
# 39997  happy mother's day mommies there, woman man lo...
# 39998  @niariley wassup beautiful!!! follow me!! peep...
# 39999  @mopedronin bullet train tokyo gf visiting jap...

# %%
# df["new_Text"].isnull().sum()

# %%
# df["new_Text"].isna().sum()

# %%
# (df["Text"]=="").sum()

# %%
# df.isnull().any(axis=1).sum()

# %%
df["sentiment"].unique()
# Out:
# array(['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
#        'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger'],
#       dtype=object)

# %%
emotion = df["sentiment"]

# %%
text  = df["new_content"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test =train_test_split(text,emotion,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline(steps=[('tfidf', TfidfVectorizer()), ('lr', LogisticRegression())])

# %%
pipe.fit(X_train,Y_train)
# Out:
# C:\Users\Asus\anaconda3\envs\py39\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('lr', LogisticRegression())])

# %%
# Fit the model to the training data
pipe.fit(X_train, Y_train)

# Evaluate the model on the test set
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predict labels
y_pred = pipe.predict(X_test)

# Accuracy
accuracy = accuracy_score(Y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}\n")

# Classification Report (includes precision, recall, F1)
print("Classification Report:")
print(classification_report(Y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(Y_test, y_pred))
# Out:
# Model Accuracy: 0.34
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        33
#      boredom       0.00      0.00      0.00        57
#        empty       0.40      0.02      0.03       242
#   enthusiasm       0.00      0.00      0.00       249
#          fun       0.16      0.03      0.05       513
#    happiness       0.33      0.37      0.35      1568
#         hate       0.43      0.14      0.21       383
#         love       0.47      0.41      0.44      1134
#      neutral       0.34      0.54      0.42      2620
#       relief       0.41      0.03      0.05       515
#      sadness       0.34      0.25      0.29      1560
#     surprise       0.27      0.04      0.07       625
#        worry       0.32      0.46      0.38      2501
#
#     accuracy                           0.34     12000
#    macro avg       0.27      0.18      0.18     12000
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.feature_extraction.text import TfidfVectorizer

pipe_svm_linear = Pipeline(steps=[
    ('tfidf', TfidfVectorizer()),
    ('svm', CalibratedClassifierCV(LinearSVC(class_weight='balanced')))
])

# %%
pipe_svm_linear.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('svm',
#                  CalibratedClassifierCV(estimator=LinearSVC(class_weight='balanced')))])

# %%
# Fit the model to the training data
pipe_svm_linear.fit(X_train, Y_train)

# Evaluate the model on the test set
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Predict labels
y_pred = pipe_svm_linear.predict(X_test)

# Accuracy
accuracy = accuracy_score(Y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}\n")

# Classification Report (includes precision, recall, F1)
print("Classification Report:")
print(classification_report(Y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(Y_test, y_pred))
# Out:
# Model Accuracy: 0.33
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        33
#      boredom       0.00      0.00      0.00        57
#        empty       0.00      0.00      0.00       242
#   enthusiasm       0.00      0.00      0.00       249
#          fun       0.08      0.00      0.01       513
#    happiness       0.33      0.34      0.33      1568
#         hate       0.38      0.14      0.21       383
#         love       0.43      0.42      0.43      1134
#      neutral       0.33      0.50      0.40      2620
#       relief       0.33      0.01      0.02       515
#      sadness       0.32      0.24      0.27      1560
#     surprise       0.57      0.01      0.01       625
#        worry       0.30      0.47      0.36      2501
#
#     accuracy                           0.33     12000
#    macro avg       0.24      0.16      0.16     12000
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Define the Random Forest pipeline
pipe_rf = Pipeline(steps=[
    ('tfidf', TfidfVectorizer()),
    ('rf', RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1))
])

# Train the model
pipe_rf.fit(X_train, Y_train)

# Predict
y_pred_rf = pipe_rf.predict(X_test)

# Evaluate
accuracy_rf = accuracy_score(Y_test, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf:.2f}\n")

print("Classification Report (Random Forest):")
print(classification_report(Y_test, y_pred_rf))

print("Confusion Matrix (Random Forest):")
print(confusion_matrix(Y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.31
#
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        33
#      boredom       0.00      0.00      0.00        57
#        empty       0.04      0.07      0.05       242
#   enthusiasm       0.05      0.00      0.01       249
#          fun       0.15      0.03      0.05       513
#    happiness       0.30      0.32      0.31      1568
#         hate       0.33      0.20      0.25       383
#         love       0.46      0.41      0.44      1134
#      neutral       0.31      0.52      0.38      2620
#       relief       0.23      0.04      0.07       515
#      sadness       0.35      0.22      0.27      1560
#     surprise       0.19      0.05      0.08       625
#        worry       0.31      0.36      0.33      2501
#
#     accuracy                           0.31     12000
#    macro avg       0.21      0.17      0.17     12000
# ...

# %%
# !pip install xgboost

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode target labels as integers
Y_train_encoded = label_encoder.fit_transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Define the pipeline with XGBoost
pipe_xgb = Pipeline(steps=[
    ('tfidf', TfidfVectorizer()),
    ('xgb', XGBClassifier(use_label_encoder=False, eval_metric='logloss', scale_pos_weight=1))
])

# Train the model
pipe_xgb.fit(X_train, Y_train_encoded)

# Predict
y_pred_xgb = pipe_xgb.predict(X_test)

# Decode predictions back to original labels
y_pred_xgb_decoded = label_encoder.inverse_transform(y_pred_xgb)

# Evaluate
accuracy_xgb = accuracy_score(Y_test, y_pred_xgb_decoded)
print(f"XGBoost Accuracy: {accuracy_xgb:.2f}\n")

print("Classification Report (XGBoost):")
print(classification_report(Y_test, y_pred_xgb_decoded))

print("Confusion Matrix (XGBoost):")
print(confusion_matrix(Y_test, y_pred_xgb_decoded))
# Out:
# C:\Users\Asus\anaconda3\envs\py39\lib\site-packages\xgboost\core.py:158: UserWarning: [23:38:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 0.34
#
# Classification Report (XGBoost):
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        33
#      boredom       0.18      0.04      0.06        57
#        empty       0.17      0.02      0.03       242
#   enthusiasm       0.11      0.00      0.01       249
#          fun       0.18      0.03      0.05       513
#    happiness       0.33      0.28      0.30      1568
#         hate       0.40      0.23      0.30       383
#         love       0.48      0.42      0.44      1134
#      neutral       0.33      0.68      0.44      2620
# ...

# %%
from sklearn.naive_bayes import MultinomialNB

# Define the pipeline with Naive Bayes
pipe_naive = Pipeline(steps=[
    ('tfidf', TfidfVectorizer()),
    ('naive_bayes', MultinomialNB())  # Using Naive Bayes
])

# Train the model
pipe_naive.fit(X_train, Y_train)

# Predict
y_pred_nb = pipe_naive.predict(X_test)

# Evaluate
accuracy_nb = accuracy_score(Y_test, y_pred_nb)
print(f"Naive Bayes Accuracy: {accuracy_nb:.2f}\n")

print("Classification Report (Naive Bayes):")
print(classification_report(Y_test, y_pred_nb))

print("Confusion Matrix (Naive Bayes):")
print(confusion_matrix(Y_test, y_pred_nb))
# Out:
# Naive Bayes Accuracy: 0.29
#
# Classification Report (Naive Bayes):
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        33
#      boredom       0.00      0.00      0.00        57
#        empty       0.00      0.00      0.00       242
#   enthusiasm       0.00      0.00      0.00       249
#          fun       0.00      0.00      0.00       513
#    happiness       0.40      0.14      0.20      1568
#         hate       0.00      0.00      0.00       383
#         love       0.58      0.17      0.26      1134
#      neutral       0.31      0.46      0.37      2620
#       relief       0.00      0.00      0.00       515
#      sadness       0.36      0.02      0.03      1560
#     surprise       0.00      0.00      0.00       625
#        worry       0.26      0.74      0.38      2501
#
#     accuracy                           0.29     12000
#    macro avg       0.15      0.12      0.10     12000
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the training labels, and transform the test labels
Y_train_encoded = label_encoder.fit_transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# List of all pipelines
pipelines = {
    'SVM Linear': pipe_svm_linear,
    'Random Forest': pipe_rf,
    'XGBoost': pipe_xgb,
    'Naive Bayes': pipe_naive,
    'Logistic Regression': pipe,  # Assuming you have defined 'pipe_naive' somewhere
}

# Store accuracy scores for comparison
accuracy_scores = {}

# Evaluate each model
for model_name, pipeline in pipelines.items():
    # Fit the model
    pipeline.fit(X_train, Y_train_encoded)
    
    # Predict
    y_pred = pipeline.predict(X_test)
    
    # Decode predictions back to the original labels
    y_pred_decoded = label_encoder.inverse_transform(y_pred)
    
    # Calculate accuracy
    accuracy = accuracy_score(Y_test, y_pred_decoded)
    accuracy_scores[model_name] = accuracy

# Create a plot to visualize the accuracy of each model
plt.figure(figsize=(10, 6))
sns.barplot(x=list(accuracy_scores.keys()), y=list(accuracy_scores.values()), palette='viridis')

# Add labels and title
plt.title('Model Accuracy Comparison', fontsize=16)
plt.xlabel('Model', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)

# Display the plot
plt.show()

# %%
ex1 = "i will kill u"

# %%
pipe_svm_linear.predict([ex1])

# %%
# Prediction Prob
pipe.predict_proba([ex1])

# %%
import joblib
pipeline_file = open("model.pkl","wb")
joblib.dump(pipe_svm_linear,pipeline_file)
pipeline_file.close()
